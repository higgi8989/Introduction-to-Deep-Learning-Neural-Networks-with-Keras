# %%
import keras

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input
from keras.utils import to_categorical

# %%
from keras.layers import Conv2D  #transforms image into feature specific form
from keras.layers import MaxPooling2D #Keeps the max of the image grids
from keras.layers import Flatten

# %%
#import data
from keras.datasets import mnist

#Load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()

#reshape the sample
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32')

# %%
X_train.shape[0]
# Out:
# 60000

# %%
#Normalizing the values
X_train = X_train / 255
X_test = X_test / 255

# %%
#changing the numbers into categorical form

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
print("Encoded y_train shape:", y_train.shape)
# Out:
# Encoded y_train shape: (60000, 10)

# %%
num_classes = y_train.shape[1] #number of possible outcomes
num_classes
# Out:
# 10

# %%
def convolution_model():

    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), strides=(1, 1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    #compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
#calling the model 
model = convolution_model()

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=200, verbose=2)

#evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/100
# 300/300 - 16s - 53ms/step - accuracy: 0.9197 - loss: 0.2923 - val_accuracy: 0.9694 - val_loss: 0.1020
# Epoch 2/100
# 300/300 - 10s - 32ms/step - accuracy: 0.9757 - loss: 0.0844 - val_accuracy: 0.9773 - val_loss: 0.0676
# Epoch 3/100
# 300/300 - 9s - 31ms/step - accuracy: 0.9835 - loss: 0.0577 - val_accuracy: 0.9852 - val_loss: 0.0469
# Epoch 4/100
# 300/300 - 10s - 33ms/step - accuracy: 0.9867 - loss: 0.0444 - val_accuracy: 0.9862 - val_loss: 0.0423
# Epoch 5/100
# 300/300 - 10s - 33ms/step - accuracy: 0.9893 - loss: 0.0357 - val_accuracy: 0.9865 - val_loss: 0.0400
# Epoch 6/100
# 300/300 - 10s - 32ms/step - accuracy: 0.9916 - loss: 0.0285 - val_accuracy: 0.9859 - val_loss: 0.0422
# Epoch 7/100
# 300/300 - 9s - 31ms/step - accuracy: 0.9929 - loss: 0.0234 - val_accuracy: 0.9883 - val_loss: 0.0367
# Epoch 8/100
# 300/300 - 10s - 32ms/step - accuracy: 0.9941 - loss: 0.0195 - val_accuracy: 0.9877 - val_loss: 0.0384
# Epoch 9/100
# ...
